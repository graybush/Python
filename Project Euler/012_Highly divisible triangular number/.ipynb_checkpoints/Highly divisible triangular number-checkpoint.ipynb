# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
import math

def divCount1(num):
    count = 1
    upper = num / 2
    upper = math.floor(upper)
    for i in range(1, upper):
        if num % i == 0:
            count += 1
    return(count)

# %%
import math

def divCount2(num):
    count = 0
    upper = math.sqrt(num)
    upper = math.ceil(upper)
    for i in range(1, upper):
        if num % i == 0:
            count += 1
    return(count * 2)

# %%
def triangleNum(number):
    n = 1
    num = 0
    divCount = 0
    while divCount < number:
        for i in range(1, number):
            num = (n * (n + 1)) / 2
            divCount = divCount2(num)
            n += 1
    return(num, divCount)

# %%
divCount2(28)

# %%
triangleNum(5)

# %%
def divCount(num):
    div = 1
    count = 0
    while div < num:
        if num % div == 0:
            count += 1
            div += 1
        else:
            div += 1
    return(count)

# %%
divCount(10)
# Out:
# 3

# %%
divCount1(10)
# Out:
# 5
# 3

# %%
divCount1(10)
# Out:
# 3

# %%
import time

% timeit[divCount(100000)]
# Out:
# 10 loops, best of 3: 24.2 ms per loop

# %%
import time

% timeit[divCount1(100000)]
# Out:
# 100 loops, best of 3: 8.21 ms per loop
